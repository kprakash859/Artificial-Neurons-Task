# %% [markdown]
# # Artificial_Neurons.AI_Internship_task

# %% [markdown]
# ## DATA VISUALIZATION

# %% [markdown]
# #### In this notebook kernal, I'm going to data visualization based on the given dataset.

# %% [markdown]
# ![SeafoodBiriyani-H5.webp](attachment:SeafoodBiriyani-H5.webp)

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing dataset
df = pd.read_csv('Tasks.csv')
df.head()
# Out:
#                        DATE DESCRIPTION  UNIT          PLACE
# 0     Friday, April 1, 2022        Beef     1    Kolenchery
# 1     Friday, April 1, 2022        Fish     1    Kolenchery
# 2     Sunday, April 3, 2022        Beef     2  Tripunithura
# 3    Tuesday, April 5, 2022      Prawns     1     Bangalore
# 4  Wednesday, April 6, 2022       Dates     1      Mangalore

# %%
df.tail(10)
# Out:
#                        DATE DESCRIPTION  UNIT     PLACE
# 101  Tuesday, June 28, 2022   King Fish     1  Kottayam
# 102  Tuesday, June 28, 2022        Beef     4  Kottayam
# 103   Tuesday, July 5, 2022      Prawns     2       NaN
# 104   Tuesday, July 5, 2022        Fish     2       NaN
# 105   Tuesday, July 5, 2022      Prawns     2       NaN
# 106   Tuesday, July 5, 2022       Lemon     4       NaN
# 107    Friday, July 8, 2022        Beef     1       NaN
# 108   Friday, July 15, 2022        Beef     1       NaN
# 109   Friday, July 15, 2022      Prawns     1       NaN
# 110   Friday, July 15, 2022       Lemon     1       NaN

# %%
df.shape
# Out:
# (111, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE         111 non-null    object
#  1   DESCRIPTION  111 non-null    object
#  2   UNIT         111 non-null    int64
#  3   PLACE        103 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 3.6+ KB

# %%
df.describe()
# Out:
#              UNIT
# count  111.000000
# mean     1.720721
# std      1.088545
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      2.000000
# max      6.000000

# %%
#Checking for null values
df.isnull().sum()
# Out:
# DATE           0
# DESCRIPTION    0
# UNIT           0
# PLACE          8
# dtype: int64

# %%
df.PLACE.mode()[0]
# Out:
# 'Malappuram'

# %%
# filling categorical missing column
df['PLACE']= df['PLACE'].fillna(df['PLACE'].mode()[0])

# %%
df.isnull().sum()
# Out:
# DATE           0
# DESCRIPTION    0
# UNIT           0
# PLACE          0
# dtype: int64

# %%
df['DESCRIPTION'].value_counts()
# Out:
# Beef          32
# Prawns        31
# Fish          13
# Mango         10
# Lemon          9
# King Fish      7
# Dates          3
# Dryfruits      3
# Dry fruits     2
# Kadumanga      1
# Name: DESCRIPTION, dtype: int64

# %%
dff=df['PLACE'].value_counts().head()
dff=pd.DataFrame(dff)
dff
# Out:
#             PLACE
# Malappuram     18
# Noida - UP      6
# Eloor           6
# Kottayam        6
# Mumbai          6

# %%
df.head()
# Out:
#                        DATE DESCRIPTION  UNIT          PLACE
# 0     Friday, April 1, 2022        Beef     1    Kolenchery
# 1     Friday, April 1, 2022        Fish     1    Kolenchery
# 2     Sunday, April 3, 2022        Beef     2  Tripunithura
# 3    Tuesday, April 5, 2022      Prawns     1     Bangalore
# 4  Wednesday, April 6, 2022       Dates     1      Mangalore

# %% [markdown]
# ### Data Visulizations

# %%
#Single variant analysis

# %%
# Beef is most sold product
df['DESCRIPTION'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
df['PLACE'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['UNIT'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df.UNIT)
# Out:
# <AxesSubplot:xlabel='UNIT', ylabel='Density'>

# %%
#Dual variant analysis

# %%
# There is single unit of any item that has sold more
sns.set_style('whitegrid')
plt.figure(figsize=(14,6))
sns.countplot(x='DESCRIPTION',hue='UNIT',data=df)
# Out:
# <AxesSubplot:xlabel='DESCRIPTION', ylabel='count'>

# %%
df['UNIT'].hist(bins=30,color='green')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='DESCRIPTION',y='UNIT',data=df)
# Out:
# <AxesSubplot:xlabel='DESCRIPTION', ylabel='UNIT'>

# %%
#Scatterplot (no info from it)
plt.figure(figsize=(15,6))
sns.scatterplot('DESCRIPTION','UNIT',data=df)
sns.set_theme(font_scale=1.5)

# %%
# Plotting the pie chart for above dataframe(Most occurance place)
plt.pie(dff["PLACE"], labels =["Malappuram","Noida","Eloor","Kottayam","Mumbai"],autopct='%1.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1dcb6bfaac0>,
# ...
#  [Text(0.2447730130080499, 1.0724207066739067, 'Malappuram'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, 'Noida'),
#   Text(-0.6858387072756794, -0.8600146903410575, 'Eloor'),
#   Text(0.24477316361895687, -1.072420672297941, 'Kottayam'),
#   Text(0.991065834488076, -0.4772719473323923, 'Mumbai')],
#  [Text(0.1335125525498454, 0.5849567490948581, '43%'),
#   Text(-0.5999999999999993, -2.808802703071063e-08, '14%'),
#   Text(-0.37409384033218873, -0.4690989220042131, '14%'),
#   Text(0.1335126347012492, -0.5849567303443314, '14%'),
#   Text(0.5405813642662232, -0.2603301530903958, '14%')])
